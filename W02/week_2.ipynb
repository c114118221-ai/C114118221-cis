# %% [markdown]
# # Mission 1：執行第一段 Python 程式

# %%
# Mission 1：第一個 Python 程式
# 定義一個變數 course_name，指定字串 "Python與資料科學"
course_name = "Python與資料科學"

# 使用 print() 輸出歡迎訊息
# 逗號會自動在項目之間加入空白
print("歡迎來到", course_name)

# %% [markdown]
# # Mission 2：變數與資料型態

# %%
# Mission 2：建立不同型態的變數
student_count = 60                    # 整數 int
average_sleep_hours = 6.7             # 浮點數 float
course_name = "Python與資料科學"       # 字串 str
has_missing_value = True              # 布林值 bool (注意大寫 T/F)

# 使用 type() 檢查每個變數的型態
print("student_count 型態：", type(student_count))
print("average_sleep_hours 型態：", type(average_sleep_hours))
print("course_name 型態：", type(course_name))
print("has_missing_value 型態：", type(has_missing_value))

# 觀察變數名稱與值的關係
print("\n--- 變數內容 ---")
print("學生人數：", student_count)
print("平均睡眠：", average_sleep_hours)
print("課程名稱：", course_name)
print("有缺失值嗎？", has_missing_value)
